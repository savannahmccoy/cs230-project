# %%
import csv
import pandas as pd
import json

# %%
meta_df = pd.read_json('meta_sub.json')
# meta_df = meta_df.T

# %%
reviews_df = pd.read_json('reviews.json')
reviews_df = reviews_df.T

# %%
meta_df
# Out:
#                                                 category tech1  \
# 38                              [Video Games, PC, Games]
# 39                              [Video Games, PC, Games]
# 41                              [Video Games, PC, Games]
# 47                                                    []
# 89     [Video Games, Kids &amp; Family, Nintendo DS, ...
# ...                                                  ...   ...
# 84758  [Video Games, Kids & Family, Nintendo 3DS, Games]
# 84770  [Video Games, Xbox One, Accessories, </span></...
# 84773    [Video Games, PC, Games, </span></span></span>]
# 84809  [Video Games, PlayStation 4, Games, </span></s...
# 84810  [Video Games, Xbox One, Games, </span></span><...
#
#                                              description fit  \
# 38     [ANNO 2070BRAND NEW - IN STOCKDVD Rom Software...
# 39     [Hitman: Absolution follows Agent 47, a cold-b...
# 41     [Dirt 3 is a popular rally racing game for Pla...
# ...

# %%
prods = list(set(reviews_df["asin"]))

# %%
len(prods)
# Out:
# 17408

# %%
# meta_df2 = meta_df[meta_df.asin.isin(prods)]
# meta_df2

# %%
# with open("meta.json", "w") as outfile:
#     json.dump(dp, outfile)

# %%
# meta_df2.to_json('meta_sub.json')
# df.to_json(r'Path to store the exported JSON file\File Name.json')

# %%
import missingno as msno

msno.bar(meta_df)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(meta_df)
# Out:
# <AxesSubplot:>

# %%
reviews_df.head(50)
# Out:
#    overall verified   reviewTime      reviewerID        asin  \
# 0        5     True  10 17, 2015  A1HP7NVNPFMA4N  0700026657
# 1        4    False  07 27, 2015  A1JGAP0185YJI6  0700026657
# 2        3     True  02 23, 2015  A1YJWEXHQBWK2B  0700026657
# 3        2     True  02 20, 2015  A2204E1TH211HT  0700026657
# 4        5     True  12 25, 2014  A2RF5B5H74JLPE  0700026657
# 5        4     True  11 13, 2014  A11V6ZJ2FVQY1D  0700026657
# 6        1    False   08 2, 2014  A1KXJ1ELZIU05C  0700026657
# 7        5     True   03 3, 2014  A1WK5I4874S3O2  0700026657
# 8        5     True  02 21, 2014   AV969NA4CBP10  0700026657
# 9        4     True  06 27, 2013  A1EO9BFUHTGWKZ  0700026657
# 10       4     True  12 28, 2012  A2M8JTIST6FPZZ  0700026657
# 11       1    False  05 15, 2012  A1LMJ9W8UX1H5B  0700026657
# 12       5     True  08 14, 2011   AN3YYDZAS3O1Y  0700099867
# 13       5    False  06 28, 2011  A38NXTZUFB1O2K  0700099867
# ...

# %%
msno.matrix(reviews_df)
# Out:
# <AxesSubplot:>

# %%
# p = list(set(reviews_df["style"]))
# p

# %%
meta_df
# Out:
#                                                 category tech1  \
# 38                              [Video Games, PC, Games]
# 39                              [Video Games, PC, Games]
# 41                              [Video Games, PC, Games]
# 47                                                    []
# 89     [Video Games, Kids &amp; Family, Nintendo DS, ...
# ...                                                  ...   ...
# 84758  [Video Games, Kids & Family, Nintendo 3DS, Games]
# 84770  [Video Games, Xbox One, Accessories, </span></...
# 84773    [Video Games, PC, Games, </span></span></span>]
# 84809  [Video Games, PlayStation 4, Games, </span></s...
# 84810  [Video Games, Xbox One, Games, </span></span><...
#
#                                              description fit  \
# 38     [ANNO 2070BRAND NEW - IN STOCKDVD Rom Software...
# 39     [Hitman: Absolution follows Agent 47, a cold-b...
# 41     [Dirt 3 is a popular rally racing game for Pla...
# ...

# %%
# list(set(meta_df["tech1"]))

# %%
# list(set(meta_df["tech2"]))

# %%
# list(set(meta_df["fit"]))
s = list(meta_df["details"])
r = [x for x in s if (x != None and x != {})]
r
# Out:
# [{'Publisher:': 'Eidos Interactive; Standard edition',
#   'ASIN:': 'B000006RGS',
#   '\n    Product Dimensions: \n    ': '5.5 x 4.8 x 0.4 inches',
#   'Shipping Weight:': '0.8 ounces ('},
#  {'Publisher:': 'Konami',
#   'ASIN:': 'B00000DMAP',
#   '\n    Product Dimensions: \n    ': '8 x 4 x 10 inches',
#   'Shipping Weight:': '1.6 ounces ('},
#  {'Publisher:': 'Playstation 1; Standard edition',
#   'ASIN:': 'B00000IKCC',
#   '\n    Package Dimensions: \n    ': '5.6 x 4.9 x 0.4 inches',
#   'Shipping Weight:': '3.2 ounces ('},
#  {'Publisher:': '989 Sports (February 17, 1999)',
#   'ASIN:': 'B00000IODY',
#   '\n    Product Dimensions: \n    ': '5.5 x 4.8 x 0.4 inches',
#   'Shipping Weight:': '3.2 ounces ('},
#  {'Language:': 'English',
#   'Domestic Shipping: ': 'Item can be shipped within U.S.',
#   'International Shipping: ': 'This item is not eligible for international shipping.',
#   'ASIN: ': 'B00000K11D'},
#  {'\n    Item Weight: \n    ': '5 ounces',
# ...

# %%
len(r)
# META: category, description, title, brand, feature, date, price, asin
# Out:
# 241

# %%
# REVIEWS: overall(rating), verified, reviewerID(user_id), asin, summary, unixReviewTime, vote, style
