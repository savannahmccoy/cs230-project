# %%
import csv
import pandas as pd
import json

# %%
meta_df = pd.read_json('meta_sub.json')

# %%
reviews_df = pd.read_json('reviews.json')
reviews_df = reviews_df.T

# %%
reviews_df.head(2)
# Out:
#   overall verified   reviewTime      reviewerID        asin reviewerName  \
# 0     5.0     True  10 17, 2015  A1HP7NVNPFMA4N  0700026657  Ambrosia075
# 1     4.0    False  07 27, 2015  A1JGAP0185YJI6  0700026657       travis
#
#                                           reviewText  \
# 0  This game is a bit hard to get the hang of, bu...
# 1  I played it a while but it was alright. The st...
#
#                                        summary unixReviewTime vote style image
# 0                  but when you do it's great.     1445040000  NaN   NaN   NaN
# 1  But in spite of that it was fun, I liked it     1437955200  NaN   NaN   NaN

# %%
meta_df.head(2)
# Out:
#                     category tech1  \
# 38  [Video Games, PC, Games]
# 39  [Video Games, PC, Games]
#
#                                           description fit  \
# 38  [ANNO 2070BRAND NEW - IN STOCKDVD Rom Software...
# 39  [Hitman: Absolution follows Agent 47, a cold-b...
#
#                      title also_buy tech2        brand  \
# 38               Anno 2070       []            Ubisoft
# 39  HITMAN ABSOLUTION (PC)       []        Square Enix
#
#                                               feature  \
# 38  [A new era: while adhering to the fundamentals...
# 39  [PC-DVD Import, Showcasing Glacier 2 technolog...
#
#                                                  rank  \
# 38  [>#30,230 in Video Games (See Top 100 in Video...
# 39  [>#58,163 in Video Games (See Top 100 in Video...
#
#                                             also_view     main_cat  \
# 38  [B013F0IP1C, B00JDP1AWU, B00XR3YC2E, B001AWMCM...  Video Games
# ...

# %% [markdown]
# **Columns to keep**
# META: category, brand, date, price, asin(productID)
# REVIEWS: overall(rating), verified, reviewerID(userID), asin(productID), summary, vote, style

# %%
# del reviews_df["reviewerName"]
# del reviews_df["reviewText"] 
# del reviews_df["summary"] 
# del reviews_df["unixReviewTime"]
# del reviews_df["image"]
del reviews_df["reviewTime"]

# %%
reviews_df.head()
# Out:
#   rating verified          userID   productID vote style
# 0    5.0     True  A1HP7NVNPFMA4N  0700026657  NaN   NaN
# 1    4.0    False  A1JGAP0185YJI6  0700026657  NaN   NaN
# 2    3.0     True  A1YJWEXHQBWK2B  0700026657  NaN   NaN
# 3    2.0     True  A2204E1TH211HT  0700026657  NaN   NaN
# 4    5.0     True  A2RF5B5H74JLPE  0700026657  NaN   NaN

# %%
reviews_df = reviews_df.rename(columns={"overall": "rating", 
                           "reviewerID": "userID", 
                           "asin": "productID"}, 
                  errors="raise")

# %%
reviews_df.head(3)
# Out:
#   rating verified          userID   productID vote style
# 0    5.0     True  A1HP7NVNPFMA4N  0700026657  NaN   NaN
# 1    4.0    False  A1JGAP0185YJI6  0700026657  NaN   NaN
# 2    3.0     True  A1YJWEXHQBWK2B  0700026657  NaN   NaN

# %%
list(reviews_df["style"])[1000]
# Out:
# {'Format:': ' Video Game'}

# %%
list(set(reviews_df["vote"]))
# Out:
# [nan,
#  '201',
#  '96',
#  '149',
#  '385',
#  '426',
#  '54',
#  '246',
#  '109',
#  '567',
#  '345',
#  '330',
#  '217',
#  '351',
#  '244',
#  '71',
#  '209',
#  '12',
#  '136',
#  '35',
#  '299',
#  '500',
#  '595',
#  '141',
#  '292',
#  '34',
#  '271',
#  '475',
#  '166',
#  '333',
#  '250',
#  '195',
#  '264',
#  '78',
#  '177',
#  '508',
#  '350',
#  '741',
#  '300',
#  '371',
#  '193',
#  '248',
#  '50',
#  '237',
#  '102',
#  '202',
#  '189',
#  '137',
#  '693',
#  '407',
#  '175',
#  '119',
#  '124',
#  '2,403',
#  '55',
#  '459',
#  '1,000',
#  '610',
#  '2,474',
#  '401',
#  '239',
#  '150',
#  '232',
#  '224',
#  '430',
#  '94',
#  '760',
#  '1,158',
#  '121',
#  '530',
#  '285',
#  '425',
#  '134',
#  '484',
#  '51',
#  '582',
#  '1,134',
#  '24',
#  '700',
#  '4',
#  '310',
#  '585',
#  '229',
#  '131',
#  '485',
#  '261',
#  '86',
#  '1,953',
#  '73',
#  '399',
#  '1,239',
#  '293',
#  '378',
#  '321',
#  '40',
#  '578',
#  '331',
#  '702',
#  '354',
#  '256',
# ...

# %%
# category, brand, price, asin(productID)
del meta_df["tech1"]
del meta_df["description"]
del meta_df["fit"] 
del meta_df["title"] 
del meta_df["also_buy"] 
del meta_df["tech2"] 
del meta_df["feature"] 
del meta_df["rank"] 
del meta_df["also_view"] 
del meta_df["main_cat"] 
del meta_df["similar_item"] 
del meta_df["date"] 
del meta_df["imageURL"]
del meta_df["imageURLHighRes"]
del meta_df["details"]

# %%
meta_df.head(3)
# Out:
#                     category        brand  price        asin
# 38  [Video Games, PC, Games]      Ubisoft  $7.95  0700026657
# 39  [Video Games, PC, Games]  Square Enix         0700026398
# 41  [Video Games, PC, Games]       Dirt 3         0700099867

# %%
len(set(meta_df["price"]))
# Out:
# 1507

# %%
len(set(meta_df["productID"]))
# Out:
# 17389

# %%
len(set(meta_df["br"]))

# %%
meta_df = meta_df.rename(columns={"asin": "productID"})

# %%
meta_df.head(3)
# Out:
#                     category        brand  price   productID
# 38  [Video Games, PC, Games]      Ubisoft  $7.95  0700026657
# 39  [Video Games, PC, Games]  Square Enix         0700026398
# 41  [Video Games, PC, Games]       Dirt 3         0700099867

# %%
meta_df.to_csv("meta_filtered.csv", index=False)

# %%
reviews_df.to_csv("reviews_filtered.csv", index=False)
