# %%
# !pip install tabgan==1.1.0
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: tabgan==1.1.0 in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: category-encoders in /usr/local/lib/python3.7/dist-packages (from tabgan==1.1.0) (2.3.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from tabgan==1.1.0) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from tabgan==1.1.0) (0.11.1+cu111)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.7/dist-packages (from tabgan==1.1.0) (2.2.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from tabgan==1.1.0) (1.1.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from tabgan==1.1.0) (1.0.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from tabgan==1.1.0) (2.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tabgan==1.1.0) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from tabgan==1.1.0) (4.62.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from category-encoders->tabgan==1.1.0) (0.5.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from category-encoders->tabgan==1.1.0) (0.10.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from category-encoders->tabgan==1.1.0) (1.4.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->tabgan==1.1.0) (2018.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.1->category-encoders->tabgan==1.1.0) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->tabgan==1.1.0) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->tabgan==1.1.0) (1.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->tabgan==1.1.0) (3.10.0.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->tabgan==1.1.0) (7.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)

# %%
from tabgan.sampler import GANGenerator, OriginalGenerator 
import csv
import pandas as pd
from sklearn.model_selection import train_test_split
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
rdf = pd.DataFrame(columns =["userID", "productID", "vote", "verified"])
tsr = pd.Series()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
  reviews_df = pd.read_csv('reviews_categorical.csv')
  reviews_df.columns = ["userID", "productID", "vote", "rating", "verified"]

# %%
for i in range(125):
    reviews_df_sub = reviews_df.sample(frac=0.03, replace=False, random_state=i)
    df_train, df_test = train_test_split(reviews_df_sub, test_size=0.2)
    df_train2 = df_train[["userID", "productID", "vote", "verified"]]
    df_test2 = df_test[["userID", "productID", "vote", "verified"]]
    df_target = df_train[["rating"]]
    new_train, new_target = GANGenerator(cat_cols=["userID", "productID", "vote", 
                                                    "verified", "rating"], 
                                          is_post_process=True, epochs=3
                                          ).generate_data_pipe(train_df=df_train2, 
                                                                test_df=df_test2, 
                                                                target=df_target, 
                                                                only_adversarial=False,
                                                                use_adversarial=True,
                                                                )
    rdf = pd.concat([rdf, new_train])  
    tsr = pd.concat([tsr, new_target])
    print("DONE: Iteration", i+1)
# Out:
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 1
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 2
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 3
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 4
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 5
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 6
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 7
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 8
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 9
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 10
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 11
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 12
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 13
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 14
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 15
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 16
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 17
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 18
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 19
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 20
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 21
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 22
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 23
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 24
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 25
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 26
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 27
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 28
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 29
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 30
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 31
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 32
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 33
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 34
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 35
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 36
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 37
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 38
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 39
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 40
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 41
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 42
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 43
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 44
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 45
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 46
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 47
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 48
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 49
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 50
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 51
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 52
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 53
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 54
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 55
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 56
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 57
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 58
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 59
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 60
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 61
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 62
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 63
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 64
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 65
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 66
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 67
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 68
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 69
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 70
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 71
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 72
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 73
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 74
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 75
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 76
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 77
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 78
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 79
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 80
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 81
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 82
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 83
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 84
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 85
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 86
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 87
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 88
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 89
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 90
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 91
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 92
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 93
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 94
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 95
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 96
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 97
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 98
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 99
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 100
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 101
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 102
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 103
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 104
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 105
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 106
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 107
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 108
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 109
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 110
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 111
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 112
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 113
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 114
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 115
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 116
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 117
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 118
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 119
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 120
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 121
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 122
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 123
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 124
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 125

# %%
f_df = pd.concat([rdf,  tsr], axis=1)
f_df.to_csv("synthetic_review_data.csv", index=False)

# %%
# rdf

# %%
# rcdf = pd.concat([rdf, new_train])

# %%
# rcdf

# %%
# f_df = pd.concat([rcdf,  dft], axis=1)
# f_df

# %%
# reviews_df.head(2)

# %%
# df_train2.head(2)

# %%
# df_test2.head(2)

# %%
# df_target.head(2)

# %%
# len(df_train2)

# %%
len(new_train)
# Out:
# 784

# %%
# new_target

# %%
#  for i in range(150):
#     reviews_df = pd.read_csv('reviews_categorical.csv')
#     reviews_df.columns = ["userID", "productID", "vote", "rating", "verified"]
#     reviews_df_sub = reviews_df.sample(frac=0.02, replace=False, random_state=i)
#     df_train, df_test = train_test_split(reviews_df_sub, test_size=0.2)
#     df_train2 = df_train[["userID", "productID", "vote", "verified"]]
#     df_test2 = df_test[["userID", "productID", "vote", "verified"]]
#     df_target = df_train[["rating"]]
#     new_train, new_target = GANGenerator(cat_cols=["userID", "productID", "vote", 
#                                                     "verified", "rating"], 
#                                           is_post_process=True, epochs=3
#                                           ).generate_data_pipe(train_df=df_train2, 
#                                                                 test_df=df_test2, 
#                                                                 target=df_target, 
#                                                                 only_adversarial=False,
#                                                                 use_adversarial=True,
#                                                                 )
#     rcdf = pd.concat([rdf, new_train])  
#     dft = pd.concat([tsr, new_target])
#     print("DONE: Iteration", i+1)
# Out:
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 1
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 2
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 3
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 4
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 5
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 6
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 7
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 8
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 9
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 10
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 11
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# DONE: Iteration 12
# Fitting CTGAN transformers for each column:   0%|          | 0/5 [00:00<?, ?it/s]
# Training CTGAN, epochs::   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-b358cea5f553> in <module>()
#      14                                                                target=df_target,
#      15                                                                only_adversarial=False,
# ---> 16                                                                use_adversarial=True,
#      17                                                                )
#      18    rcdf = pd.concat([rdf, new_train])
#
# /usr/local/lib/python3.7/dist-packages/tabgan/abc_sampler.py in generate_data_pipe(self, train_df, target, test_df, deep_copy, only_adversarial, use_adversarial, only_generated_data)
#      67             logging.info("Starting generation step.")
#      68             new_train, new_target = generator.generate_data(
# ---> 69                 new_train, new_target, test_df, only_generated_data
#      70             )
#      71             logging.info("Starting postprocessing step.")
#
# /usr/local/lib/python3.7/dist-packages/tabgan/sampler.py in generate_data(self, train_df, target, test_df, only_generated_data)
#     248             ctgan.fit(train_df, [], epochs=self.epochs)
#     249         else:
# --> 250             ctgan.fit(train_df, self.cat_cols, epochs=self.epochs)
#     251         logging.info("Finished training GAN")
#     252         generated_df = ctgan.sample(
#
# /usr/local/lib/python3.7/dist-packages/_ctgan/synthesizer.py in fit(self, train_data, discrete_columns, epochs, log_frequency)
#     236                 )
#     237                 loss_d = -(torch.mean(y_real) - torch.mean(y_fake))
# --> 238                 train_losses.append(loss_d.item())
#     239                 optimizerD.zero_grad()
#     240                 pen.backward(retain_graph=True)
#
# KeyboardInterrupt:

# %%
# meta_df.head(2)

# %%
# meta_df = pd.read_csv('meta_categorical.csv')
